# %% [markdown]
# # Vizdoom
#
# https://youtu.be/eBCU-tqLGfQ

# %%
from vizdoom import *

import random
import time

import numpy as np

# %%
game = DoomGame()
game.load_config('github/VizDoom/scenarios/basic.cfg')
game.init()

# %%
game.new_episode()

# This is the set of actions we can take in the environment.
actions = np.identity(3, dtype=np.uint8)

episodes = 1
for episode in range(episodes):
    game.new_episode()
    while not game.is_episode_finished():
        # get the state
        state = game.get_state()
        
        # get the screen buffer
        img = state.screen_buffer
        
        
        info = state.game_variables
        
        # choose action
        action = random.choice(actions)
        
        # take action and get reward
        reward = game.make_action(action, 4)
        
        # print reward
        print('reward: ', reward)
        time.sleep(0.02)
    time.sleep(2)
# Out:
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -9.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0
# reward:  -4.0

# %%
game.get_state()

# %%
game.new_episode()
print(game.get_state().screen_buffer.shape)
game.close()
# Out:
# (3, 240, 320)

# %% [markdown]
# ## 2. Converting it in a Gym environment

# %%
from gym import Env
from gym.spaces import Discrete, Box
import cv2

# %%
class VizDoomGym(Env):
    """VizDoom OpenAI Gym environment"""
    
    def __init__(self, render=False):
        """Initialize the environment"""
        
        # inherit from the base class
        super().__init__()
        
        # Setup the game
        self.game = DoomGame()
        self.game.load_config('github/VizDoom/scenarios/basic.cfg')
        
        # Render frame logic
        if render == False:
            self.game.set_window_visible(False)
        else:
            self.game.set_window_visible(True)
            
        self.game.init()
        
        # create the action space and observation space
        self.observation_space = Box(
            low=0, 
            high=255, 
            shape=(100, 160, 1), 
            dtype=np.uint8
            )
        self.action_space = Discrete(3)
        
        
    def step(self, action):
        """Take a step in the environment"""
        
        actions = np.identity(3, dtype=np.uint8)
        reward = self.game.make_action(actions[action], 4)
        
        if self.game.get_state():
            # if we get a state
            
            state = self.game.get_state().screen_buffer
            state = self.grayscale(state) # transform the image to grayscale
            info = self.game.get_state().game_variables
        else:
            state = np.zeros(self.observation_space.shape)
            info = 0

        info = {"info": info}
        done = self.game.is_episode_finished()

        return state, reward, done, info # our state is the image
        
    def close(self):
        """close the environment"""
        
        self.game.close()
        
    def render():
        """Render the environment"""
        pass
    def grayscale(self, observation):
        """Transform the image to grayscale"""
        
        gray = cv2.cvtColor(
            np.moveaxis(observation, 0, -1), # reorders observation shape from (3, 240, 320) to (240, 320, 3)
            cv2.COLOR_RGB2GRAY
            )
        
        # make image smaller
        resize = cv2.resize(gray, (160, 100), interpolation=cv2.INTER_CUBIC)
        state = np.reshape(resize, (100, 160, 1))
        
        return state
    
    def reset(self):
        """Reset the environment"""
        
        self.game.new_episode()
        state = self.game.get_state().screen_buffer
        return self.grayscale(state)

# %%
env=VizDoomGym()

# %%
state = env.reset()

# %%
state.shape
# Out:
# (100, 160, 1)

# %% [markdown]
# ### 2.1 Environment checker

# %%
from stable_baselines3.common import env_checker

# %%
env_checker.check_env(env)

# %% [markdown]
# ## 3. View Environment

# %%
from matplotlib import pyplot as plt
plt.imshow(cv2.cvtColor(state, cv2.COLOR_BGR2RGB))

# %%
env.close()

# %% [markdown]
# ## 4. Setup Callback

# %%
import os
from stable_baselines3.common.callbacks import BaseCallback

# %%
class TrainAndLoggingCallback(BaseCallback):
    
    def __init__(self, check_freq, save_path, verbose=1):
        super(TrainAndLoggingCallback, self).__init__(verbose)
        self.check_freq = check_freq
        self.save_path = save_path
        
    def _init_callback(self):
        if self.save_path is not None:
            os.makedirs(self.save_path, exist_ok = True)
            
    def _on_step(self):
        if self.n_calls % self.check_freq == 0:
            model_path = os.path.join(self.save_path, 'best_model_{}'.format(self.n_calls))
            self.model.save(model_path)
            
        return True

# %%
CHECKPOINT_DIR = './train/train_basic'
LOG_DIR = './train/log_basic'

# %%
callback = TrainAndLoggingCallback(check_freq=10_000, save_path=CHECKPOINT_DIR)

# %% [markdown]
# ## 5. Train Model

# %%
from stable_baselines3 import PPO

# %%
env = VizDoomGym()

# %%
model = PPO(
    'CnnPolicy', 
    env, 
    tensorboard_log=LOG_DIR, 
    verbose=1, 
    learning_rate=0.0001, 
    n_steps=256
    )
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.

# %%
model.learn(
    total_timesteps=100_000, 
    callback=callback
    )
# Out:
# Logging to ./train/log_basic\PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 31       |
# |    ep_rew_mean     | -73.1    |
# | time/              |          |
# |    fps             | 26       |
# |    iterations      | 1        |
# |    time_elapsed    | 9        |
# |    total_timesteps | 256      |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 32.7        |
# |    ep_rew_mean          | -71.5       |
# | time/                   |             |
# |    fps                  | 33          |
# |    iterations           | 2           |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 512         |
# | train/                  |             |
# |    approx_kl            | 0.006950658 |
# |    clip_fraction        | 0.0953      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | -0.000361   |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.24e+03    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | 0.000518    |
# |    value_loss           | 2.63e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 30.7        |
# |    ep_rew_mean          | -67.6       |
# | time/                   |             |
# |    fps                  | 43          |
# |    iterations           | 3           |
# |    time_elapsed         | 17          |
# |    total_timesteps      | 768         |
# | train/                  |             |
# |    approx_kl            | 0.019706797 |
# |    clip_fraction        | 0.0906      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.00197     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | 0.000145    |
# |    value_loss           | 3.51e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31           |
# |    ep_rew_mean          | -73.7        |
# | time/                   |              |
# |    fps                  | 51           |
# |    iterations           | 4            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 1024         |
# | train/                  |              |
# |    approx_kl            | 0.0039489106 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | 0.0214       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.24e+03     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000514    |
# |    value_loss           | 4.39e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 33.1        |
# |    ep_rew_mean          | -86.1       |
# | time/                   |             |
# |    fps                  | 59          |
# |    iterations           | 5           |
# |    time_elapsed         | 21          |
# |    total_timesteps      | 1280        |
# | train/                  |             |
# |    approx_kl            | 0.029313251 |
# |    clip_fraction        | 0.29        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.0332      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.37e+03    |
# |    n_updates            | 40          |
# |    policy_gradient_loss | 0.021       |
# |    value_loss           | 3.56e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 34.4       |
# |    ep_rew_mean          | -93.3      |
# | time/                   |            |
# |    fps                  | 64         |
# |    iterations           | 6          |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 1536       |
# | train/                  |            |
# |    approx_kl            | 0.03979495 |
# |    clip_fraction        | 0.321      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.08      |
# |    explained_variance   | -0.0134    |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.49e+03   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | 0.00594    |
# |    value_loss           | 3.47e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 35.8       |
# |    ep_rew_mean          | -99.1      |
# | time/                   |            |
# |    fps                  | 69         |
# |    iterations           | 7          |
# |    time_elapsed         | 25         |
# |    total_timesteps      | 1792       |
# | train/                  |            |
# |    approx_kl            | 0.01879866 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.04      |
# |    explained_variance   | 0.0139     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.42e+03   |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.00351   |
# |    value_loss           | 4.15e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 35.1        |
# |    ep_rew_mean          | -95         |
# | time/                   |             |
# |    fps                  | 74          |
# |    iterations           | 8           |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 2048        |
# | train/                  |             |
# |    approx_kl            | 0.029121365 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | -0.0105     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.28e+03    |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.000157   |
# |    value_loss           | 4.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 37.7        |
# |    ep_rew_mean          | -112        |
# | time/                   |             |
# |    fps                  | 79          |
# |    iterations           | 9           |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.006613679 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.05       |
# |    explained_variance   | 0.0179      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.4e+03     |
# |    n_updates            | 80          |
# |    policy_gradient_loss | 0.0113      |
# |    value_loss           | 5.16e+03    |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 37.8      |
# |    ep_rew_mean          | -114      |
# | time/                   |           |
# |    fps                  | 82        |
# |    iterations           | 10        |
# |    time_elapsed         | 30        |
# |    total_timesteps      | 2560      |
# | train/                  |           |
# |    approx_kl            | 0.0089748 |
# |    clip_fraction        | 0.554     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.01     |
# |    explained_variance   | -0.0148   |
# |    learning_rate        | 0.0001    |
# |    loss                 | 1.01e+03  |
# |    n_updates            | 90        |
# |    policy_gradient_loss | 0.0341    |
# |    value_loss           | 1.96e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 39.3        |
# |    ep_rew_mean          | -123        |
# | time/                   |             |
# |    fps                  | 85          |
# |    iterations           | 11          |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 2816        |
# | train/                  |             |
# |    approx_kl            | 0.006481851 |
# |    clip_fraction        | 0.0758      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.06       |
# |    explained_variance   | 0.0342      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.58e+03    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | 0.00102     |
# |    value_loss           | 3.05e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.9         |
# |    ep_rew_mean          | -126         |
# | time/                   |              |
# |    fps                  | 88           |
# |    iterations           | 12           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0099990405 |
# |    clip_fraction        | 0.246        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.05        |
# |    explained_variance   | -0.00681     |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.8e+03      |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00318     |
# |    value_loss           | 3.35e+03     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 40.9      |
# |    ep_rew_mean          | -132      |
# | time/                   |           |
# |    fps                  | 91        |
# |    iterations           | 13        |
# |    time_elapsed         | 36        |
# |    total_timesteps      | 3328      |
# | train/                  |           |
# |    approx_kl            | 0.0315514 |
# |    clip_fraction        | 0.247     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.03     |
# |    explained_variance   | 0.0234    |
# |    learning_rate        | 0.0001    |
# |    loss                 | 3.12e+03  |
# |    n_updates            | 120       |
# |    policy_gradient_loss | 0.00174   |
# |    value_loss           | 5.51e+03  |
# ---------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 40.4       |
# |    ep_rew_mean          | -130       |
# | time/                   |            |
# |    fps                  | 93         |
# |    iterations           | 14         |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 3584       |
# | train/                  |            |
# |    approx_kl            | 0.09247856 |
# |    clip_fraction        | 0.605      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.03      |
# |    explained_variance   | 0.0467     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.06e+03   |
# |    n_updates            | 130        |
# |    policy_gradient_loss | 0.0462     |
# |    value_loss           | 3.86e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.1        |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 93          |
# |    iterations           | 15          |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 3840        |
# | train/                  |             |
# |    approx_kl            | 0.059376545 |
# |    clip_fraction        | 0.489       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.838      |
# |    explained_variance   | 0.0331      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.1e+03     |
# |    n_updates            | 140         |
# |    policy_gradient_loss | 0.0671      |
# |    value_loss           | 5.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.9        |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 16          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.003088491 |
# |    clip_fraction        | 0.0355      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.928      |
# |    explained_variance   | -0.039      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.6e+03     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.000707   |
# |    value_loss           | 4.28e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.1        |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 96          |
# |    iterations           | 17          |
# |    time_elapsed         | 45          |
# |    total_timesteps      | 4352        |
# | train/                  |             |
# |    approx_kl            | 0.015922429 |
# |    clip_fraction        | 0.576       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.922      |
# |    explained_variance   | 0.0565      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.78e+03    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | 0.0515      |
# |    value_loss           | 3.81e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.4       |
# |    ep_rew_mean          | -142       |
# | time/                   |            |
# |    fps                  | 97         |
# |    iterations           | 18         |
# |    time_elapsed         | 47         |
# |    total_timesteps      | 4608       |
# | train/                  |            |
# |    approx_kl            | 0.02156486 |
# |    clip_fraction        | 0.219      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.01      |
# |    explained_variance   | 0.0173     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.8e+03    |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0073    |
# |    value_loss           | 6.11e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 41.2       |
# |    ep_rew_mean          | -142       |
# | time/                   |            |
# |    fps                  | 98         |
# |    iterations           | 19         |
# |    time_elapsed         | 49         |
# |    total_timesteps      | 4864       |
# | train/                  |            |
# |    approx_kl            | 0.06311796 |
# |    clip_fraction        | 0.413      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.988     |
# |    explained_variance   | 0.0176     |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.42e+03   |
# |    n_updates            | 180        |
# |    policy_gradient_loss | 0.0141     |
# |    value_loss           | 4.7e+03    |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 40.9         |
# |    ep_rew_mean          | -139         |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 20           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 5120         |
# | train/                  |              |
# |    approx_kl            | 0.0056368466 |
# |    clip_fraction        | 0.341        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.852       |
# |    explained_variance   | 0.0656       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.17e+03     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | 0.00551      |
# |    value_loss           | 7.26e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 39.3         |
# |    ep_rew_mean          | -131         |
# | time/                   |              |
# |    fps                  | 99           |
# |    iterations           | 21           |
# |    time_elapsed         | 53           |
# |    total_timesteps      | 5376         |
# | train/                  |              |
# |    approx_kl            | 0.0019123694 |
# |    clip_fraction        | 0.0762       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.854       |
# |    explained_variance   | 0.0584       |
# |    learning_rate        | 0.0001       |
# |    loss                 | 3.04e+03     |
# |    n_updates            | 200          |
# |    policy_gradient_loss | 0.00213      |
# |    value_loss           | 6.17e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 36.3       |
# |    ep_rew_mean          | -115       |
# | time/                   |            |
# |    fps                  | 100        |
# |    iterations           | 22         |
# |    time_elapsed         | 55         |
# |    total_timesteps      | 5632       |
# | train/                  |            |
# |    approx_kl            | 0.01923859 |
# |    clip_fraction        | 0.15       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.859     |
# |    explained_variance   | 0.161      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.78e+03   |
# |    n_updates            | 210        |
# |    policy_gradient_loss | 0.00853    |
# |    value_loss           | 6.82e+03   |
# ----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 35.3          |
# |    ep_rew_mean          | -109          |
# | time/                   |               |
# |    fps                  | 102           |
# |    iterations           | 23            |
# |    time_elapsed         | 57            |
# |    total_timesteps      | 5888          |
# | train/                  |               |
# |    approx_kl            | 0.00056121196 |
# |    clip_fraction        | 0.0355        |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.865        |
# |    explained_variance   | 0.06          |
# |    learning_rate        | 0.0001        |
# |    loss                 | 2.38e+03      |
# |    n_updates            | 220           |
# |    policy_gradient_loss | -0.00211      |
# |    value_loss           | 5.82e+03      |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.4         |
# |    ep_rew_mean          | -86.7        |
# | time/                   |              |
# |    fps                  | 104          |
# |    iterations           | 24           |
# |    time_elapsed         | 58           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0059239855 |
# |    clip_fraction        | 0.0668       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.85        |
# |    explained_variance   | 0.113        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.45e+03     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.000557    |
# |    value_loss           | 4.92e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 30.1         |
# |    ep_rew_mean          | -81          |
# | time/                   |              |
# |    fps                  | 105          |
# |    iterations           | 25           |
# |    time_elapsed         | 60           |
# |    total_timesteps      | 6400         |
# | train/                  |              |
# |    approx_kl            | 0.0038976225 |
# |    clip_fraction        | 0.0746       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.866       |
# |    explained_variance   | 0.208        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 2.94e+03     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00509     |
# |    value_loss           | 6.03e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.3        |
# |    ep_rew_mean          | -76.2       |
# | time/                   |             |
# |    fps                  | 106         |
# |    iterations           | 26          |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 6656        |
# | train/                  |             |
# |    approx_kl            | 0.008521423 |
# |    clip_fraction        | 0.0426      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.844      |
# |    explained_variance   | 0.156       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.06e+03    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 3.8e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.1        |
# |    ep_rew_mean          | -75.4       |
# | time/                   |             |
# |    fps                  | 107         |
# |    iterations           | 27          |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 6912        |
# | train/                  |             |
# |    approx_kl            | 0.006883424 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.848      |
# |    explained_variance   | 0.0572      |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.71e+03    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 5.56e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.3        |
# |    ep_rew_mean          | -69.5       |
# | time/                   |             |
# |    fps                  | 108         |
# |    iterations           | 28          |
# |    time_elapsed         | 65          |
# |    total_timesteps      | 7168        |
# | train/                  |             |
# |    approx_kl            | 0.015372709 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.851      |
# |    explained_variance   | 0.18        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.07e+03    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | 0.00792     |
# |    value_loss           | 3.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.9        |
# |    ep_rew_mean          | -68.3       |
# | time/                   |             |
# |    fps                  | 110         |
# |    iterations           | 29          |
# |    time_elapsed         | 67          |
# |    total_timesteps      | 7424        |
# | train/                  |             |
# |    approx_kl            | 0.020552196 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.759      |
# |    explained_variance   | 0.201       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.4e+03     |
# |    n_updates            | 280         |
# |    policy_gradient_loss | 0.00238     |
# |    value_loss           | 5.55e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.6        |
# |    ep_rew_mean          | -65.1       |
# | time/                   |             |
# |    fps                  | 111         |
# |    iterations           | 30          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 7680        |
# | train/                  |             |
# |    approx_kl            | 0.013002777 |
# |    clip_fraction        | 0.159       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.805      |
# |    explained_variance   | 0.299       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.58e+03    |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0128     |
# |    value_loss           | 3.73e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 26.7       |
# |    ep_rew_mean          | -60.1      |
# | time/                   |            |
# |    fps                  | 112        |
# |    iterations           | 31         |
# |    time_elapsed         | 70         |
# |    total_timesteps      | 7936       |
# | train/                  |            |
# |    approx_kl            | 0.00830892 |
# |    clip_fraction        | 0.0949     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.783     |
# |    explained_variance   | 0.403      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.96e+03   |
# |    n_updates            | 300        |
# |    policy_gradient_loss | 0.00153    |
# |    value_loss           | 4.32e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.2         |
# |    ep_rew_mean          | -57.3        |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 32           |
# |    time_elapsed         | 71           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0074655293 |
# |    clip_fraction        | 0.155        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.907       |
# |    explained_variance   | 0.611        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.44e+03     |
# |    n_updates            | 310          |
# |    policy_gradient_loss | 0.000721     |
# |    value_loss           | 3.23e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.7        |
# |    ep_rew_mean          | -54.6       |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 33          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 8448        |
# | train/                  |             |
# |    approx_kl            | 0.005761008 |
# |    clip_fraction        | 0.128       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.868      |
# |    explained_variance   | 0.594       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.24e+03    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00549    |
# |    value_loss           | 4.3e+03     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25.7       |
# |    ep_rew_mean          | -54.6      |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 34         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 8704       |
# | train/                  |            |
# |    approx_kl            | 0.03280428 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.831     |
# |    explained_variance   | 0.696      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.07e+03   |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.00245   |
# |    value_loss           | 2.21e+03   |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 25         |
# |    ep_rew_mean          | -49.3      |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 35         |
# |    time_elapsed         | 77         |
# |    total_timesteps      | 8960       |
# | train/                  |            |
# |    approx_kl            | 0.01221284 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.821     |
# |    explained_variance   | 0.576      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 2.72e+03   |
# |    n_updates            | 340        |
# |    policy_gradient_loss | 0.00404    |
# |    value_loss           | 3.53e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.9         |
# |    ep_rew_mean          | -62.3        |
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 36           |
# |    time_elapsed         | 79           |
# |    total_timesteps      | 9216         |
# | train/                  |              |
# |    approx_kl            | 0.0045154616 |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.907       |
# |    explained_variance   | 0.766        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.08e+03     |
# |    n_updates            | 350          |
# |    policy_gradient_loss | 0.00215      |
# |    value_loss           | 2.39e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26           |
# |    ep_rew_mean          | -56.1        |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 37           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 9472         |
# | train/                  |              |
# |    approx_kl            | 0.0060105193 |
# |    clip_fraction        | 0.191        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.957       |
# |    explained_variance   | 0.078        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.69e+03     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | 0.00511      |
# |    value_loss           | 3.29e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.9        |
# |    ep_rew_mean          | -61.9       |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 38          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 9728        |
# | train/                  |             |
# |    approx_kl            | 0.009673476 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.945      |
# |    explained_variance   | 0.621       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 989         |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.00715    |
# |    value_loss           | 2.26e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.8         |
# |    ep_rew_mean          | -67          |
# | time/                   |              |
# |    fps                  | 116          |
# |    iterations           | 39           |
# |    time_elapsed         | 85           |
# |    total_timesteps      | 9984         |
# | train/                  |              |
# |    approx_kl            | 0.0064580403 |
# |    clip_fraction        | 0.0949       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.81        |
# |    explained_variance   | 0.67         |
# |    learning_rate        | 0.0001       |
# |    loss                 | 850          |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00163     |
# |    value_loss           | 2.91e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.1        |
# |    ep_rew_mean          | -74.8       |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 40          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.009344542 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.865      |
# |    explained_variance   | 0.499       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.32e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | 0.00201     |
# |    value_loss           | 3.52e+03    |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 28.8       |
# |    ep_rew_mean          | -73.4      |
# | time/                   |            |
# |    fps                  | 115        |
# |    iterations           | 41         |
# |    time_elapsed         | 91         |
# |    total_timesteps      | 10496      |
# | train/                  |            |
# |    approx_kl            | 0.01183442 |
# |    clip_fraction        | 0.179      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.875     |
# |    explained_variance   | 0.293      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 1.74e+03   |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.00109   |
# |    value_loss           | 4.18e+03   |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 29.9        |
# |    ep_rew_mean          | -80.3       |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 42          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 10752       |
# | train/                  |             |
# |    approx_kl            | 0.008750064 |
# |    clip_fraction        | 0.155       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.739      |
# |    explained_variance   | 0.67        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 824         |
# |    n_updates            | 410         |
# |    policy_gradient_loss | 0.00478     |
# |    value_loss           | 2.3e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 31.2        |
# |    ep_rew_mean          | -88.3       |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 43          |
# |    time_elapsed         | 96          |
# |    total_timesteps      | 11008       |
# | train/                  |             |
# |    approx_kl            | 0.007383542 |
# |    clip_fraction        | 0.0734      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.587       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.07e+03    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0021     |
# |    value_loss           | 2.35e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.8         |
# |    ep_rew_mean          | -91.4        |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 44           |
# |    time_elapsed         | 99           |
# |    total_timesteps      | 11264        |
# | train/                  |              |
# |    approx_kl            | 0.0032945168 |
# |    clip_fraction        | 0.0926       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.775       |
# |    explained_variance   | 0.696        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.15e+03     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | 0.00554      |
# |    value_loss           | 2.73e+03     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 33.5      |
# |    ep_rew_mean          | -101      |
# | time/                   |           |
# |    fps                  | 113       |
# |    iterations           | 45        |
# |    time_elapsed         | 101       |
# |    total_timesteps      | 11520     |
# | train/                  |           |
# |    approx_kl            | 0.0139104 |
# |    clip_fraction        | 0.0887    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.721    |
# |    explained_variance   | 0.453     |
# |    learning_rate        | 0.0001    |
# |    loss                 | 1.77e+03  |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -0.00173  |
# |    value_loss           | 3.73e+03  |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.5        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 113         |
# |    iterations           | 46          |
# |    time_elapsed         | 103         |
# |    total_timesteps      | 11776       |
# | train/                  |             |
# |    approx_kl            | 0.005994454 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.653      |
# |    explained_variance   | 0.676       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.2e+03     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.00194    |
# |    value_loss           | 3.02e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 36.1         |
# |    ep_rew_mean          | -117         |
# | time/                   |              |
# |    fps                  | 113          |
# |    iterations           | 47           |
# |    time_elapsed         | 105          |
# |    total_timesteps      | 12032        |
# | train/                  |              |
# |    approx_kl            | 0.0046307417 |
# |    clip_fraction        | 0.0871       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.704       |
# |    explained_variance   | 0.318        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 749          |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -0.00099     |
# |    value_loss           | 1.96e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34.5        |
# |    ep_rew_mean          | -106        |
# | time/                   |             |
# |    fps                  | 114         |
# |    iterations           | 48          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.012285537 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.639      |
# |    explained_variance   | 0.57        |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.21e+03    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | 0.0161      |
# |    value_loss           | 3.5e+03     |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 31.9         |
# |    ep_rew_mean          | -87.9        |
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 49           |
# |    time_elapsed         | 108          |
# |    total_timesteps      | 12544        |
# | train/                  |              |
# |    approx_kl            | 0.0068162447 |
# |    clip_fraction        | 0.0852       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.482       |
# |    explained_variance   | 0.788        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.83e+03     |
# |    n_updates            | 480          |
# |    policy_gradient_loss | 0.00178      |
# |    value_loss           | 3.03e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.5        |
# |    ep_rew_mean          | -66.2       |
# | time/                   |             |
# |    fps                  | 115         |
# |    iterations           | 50          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 12800       |
# | train/                  |             |
# |    approx_kl            | 0.018267814 |
# |    clip_fraction        | 0.1         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.553      |
# |    explained_variance   | 0.847       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 638         |
# |    n_updates            | 490         |
# |    policy_gradient_loss | -0.0139     |
# |    value_loss           | 1.44e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.2         |
# |    ep_rew_mean          | -50.5        |
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 51           |
# |    time_elapsed         | 113          |
# |    total_timesteps      | 13056        |
# | train/                  |              |
# |    approx_kl            | 0.0026996143 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.541       |
# |    explained_variance   | 0.782        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.09e+03     |
# |    n_updates            | 500          |
# |    policy_gradient_loss | -0.00365     |
# |    value_loss           | 3e+03        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.9         |
# |    ep_rew_mean          | -61.1        |
# | time/                   |              |
# |    fps                  | 115          |
# |    iterations           | 52           |
# |    time_elapsed         | 115          |
# |    total_timesteps      | 13312        |
# | train/                  |              |
# |    approx_kl            | 0.0076518543 |
# |    clip_fraction        | 0.0523       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.551       |
# |    explained_variance   | 0.808        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.26e+03     |
# |    n_updates            | 510          |
# |    policy_gradient_loss | 0.00472      |
# |    value_loss           | 2.28e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27          |
# |    ep_rew_mean          | -54.4       |
# | time/                   |             |
# |    fps                  | 116         |
# |    iterations           | 53          |
# |    time_elapsed         | 116         |
# |    total_timesteps      | 13568       |
# | train/                  |             |
# |    approx_kl            | 0.011937114 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.693      |
# |    explained_variance   | -0.0581     |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.11e+03    |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 3.31e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 27.1         |
# |    ep_rew_mean          | -55.3        |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 54           |
# |    time_elapsed         | 118          |
# |    total_timesteps      | 13824        |
# | train/                  |              |
# |    approx_kl            | 0.0105731655 |
# |    clip_fraction        | 0.19         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.631       |
# |    explained_variance   | 0.686        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.74e+03     |
# |    n_updates            | 530          |
# |    policy_gradient_loss | 0.0115       |
# |    value_loss           | 2.6e+03      |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.3         |
# |    ep_rew_mean          | -32.2        |
# | time/                   |              |
# |    fps                  | 117          |
# |    iterations           | 55           |
# |    time_elapsed         | 119          |
# |    total_timesteps      | 14080        |
# | train/                  |              |
# |    approx_kl            | 0.0076632695 |
# |    clip_fraction        | 0.0488       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.662       |
# |    explained_variance   | 0.832        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 634          |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00303     |
# ...
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.9        |
# |    ep_rew_mean          | -66.2       |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 99          |
# |    time_elapsed         | 189         |
# |    total_timesteps      | 25344       |
# | train/                  |             |
# |    approx_kl            | 0.016779676 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.656      |
# |    explained_variance   | 0.912       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 358         |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 860         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.5        |
# |    ep_rew_mean          | -58.7       |
# | time/                   |             |
# |    fps                  | 133         |
# |    iterations           | 100         |
# |    time_elapsed         | 191         |
# |    total_timesteps      | 25600       |
# | train/                  |             |
# |    approx_kl            | 0.012918373 |
# |    clip_fraction        | 0.267       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 648         |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.00441    |
# |    value_loss           | 1.21e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.8        |
# |    ep_rew_mean          | -55.4       |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 101         |
# |    time_elapsed         | 192         |
# |    total_timesteps      | 25856       |
# | train/                  |             |
# |    approx_kl            | 0.013525348 |
# |    clip_fraction        | 0.0766      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.662      |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 562         |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.00613    |
# |    value_loss           | 919         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.3         |
# |    ep_rew_mean          | -52          |
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 102          |
# |    time_elapsed         | 194          |
# |    total_timesteps      | 26112        |
# | train/                  |              |
# |    approx_kl            | 0.0111531075 |
# |    clip_fraction        | 0.161        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.679       |
# |    explained_variance   | 0.768        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 787          |
# |    n_updates            | 1010         |
# |    policy_gradient_loss | -0.00809     |
# |    value_loss           | 2.2e+03      |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | -38.4       |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 103         |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 26368       |
# | train/                  |             |
# |    approx_kl            | 0.013327863 |
# |    clip_fraction        | 0.0992      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.657      |
# |    explained_variance   | 0.861       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 469         |
# |    n_updates            | 1020        |
# |    policy_gradient_loss | -0.00398    |
# |    value_loss           | 1.53e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 22.4         |
# |    ep_rew_mean          | -34.5        |
# | time/                   |              |
# |    fps                  | 134          |
# |    iterations           | 104          |
# |    time_elapsed         | 198          |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0030288147 |
# |    clip_fraction        | 0.131        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.571       |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 511          |
# |    n_updates            | 1030         |
# |    policy_gradient_loss | -0.00204     |
# |    value_loss           | 1.27e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 23.4       |
# |    ep_rew_mean          | -41.3      |
# | time/                   |            |
# |    fps                  | 134        |
# |    iterations           | 105        |
# |    time_elapsed         | 199        |
# |    total_timesteps      | 26880      |
# | train/                  |            |
# |    approx_kl            | 0.09002657 |
# |    clip_fraction        | 0.327      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.562     |
# |    explained_variance   | 0.924      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 502        |
# |    n_updates            | 1040       |
# |    policy_gradient_loss | 0.0184     |
# |    value_loss           | 832        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.1        |
# |    ep_rew_mean          | -39.3       |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 106         |
# |    time_elapsed         | 201         |
# |    total_timesteps      | 27136       |
# | train/                  |             |
# |    approx_kl            | 0.013207428 |
# |    clip_fraction        | 0.0898      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 674         |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | 0.00188     |
# |    value_loss           | 1.38e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 23.4        |
# |    ep_rew_mean          | -41.4       |
# | time/                   |             |
# |    fps                  | 134         |
# |    iterations           | 107         |
# |    time_elapsed         | 203         |
# |    total_timesteps      | 27392       |
# | train/                  |             |
# |    approx_kl            | 0.015967647 |
# |    clip_fraction        | 0.0914      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.612      |
# |    explained_variance   | 0.439       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.99e+03    |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | 0.00634     |
# |    value_loss           | 5.4e+03     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 22.7        |
# |    ep_rew_mean          | -35.9       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 108         |
# |    time_elapsed         | 204         |
# |    total_timesteps      | 27648       |
# | train/                  |             |
# |    approx_kl            | 0.033584304 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.569      |
# |    explained_variance   | 0.638       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 2.24e+03    |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.00258    |
# |    value_loss           | 3.23e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 24.3        |
# |    ep_rew_mean          | -45.7       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 109         |
# |    time_elapsed         | 206         |
# |    total_timesteps      | 27904       |
# | train/                  |             |
# |    approx_kl            | 0.004430535 |
# |    clip_fraction        | 0.0879      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.497      |
# |    explained_variance   | 0.672       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 1.27e+03    |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | 0.00282     |
# |    value_loss           | 3.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 25.6        |
# |    ep_rew_mean          | -53.4       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 110         |
# |    time_elapsed         | 207         |
# |    total_timesteps      | 28160       |
# | train/                  |             |
# |    approx_kl            | 0.020361554 |
# |    clip_fraction        | 0.167       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.54       |
# |    explained_variance   | 0.773       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 496         |
# |    n_updates            | 1090        |
# |    policy_gradient_loss | -0.000949   |
# |    value_loss           | 1.88e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 25.1         |
# |    ep_rew_mean          | -48.8        |
# | time/                   |              |
# |    fps                  | 135          |
# |    iterations           | 111          |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 28416        |
# | train/                  |              |
# |    approx_kl            | 0.0022304442 |
# |    clip_fraction        | 0.0672       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.473       |
# |    explained_variance   | 0.424        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.19e+03     |
# |    n_updates            | 1100         |
# |    policy_gradient_loss | 0.00325      |
# |    value_loss           | 2.97e+03     |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 23.3         |
# |    ep_rew_mean          | -37.3        |
# | time/                   |              |
# |    fps                  | 135          |
# |    iterations           | 112          |
# |    time_elapsed         | 211          |
# |    total_timesteps      | 28672        |
# | train/                  |              |
# |    approx_kl            | 0.0025262244 |
# |    clip_fraction        | 0.13         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.444       |
# |    explained_variance   | 0.827        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 677          |
# |    n_updates            | 1110         |
# |    policy_gradient_loss | -0.00236     |
# |    value_loss           | 1.74e+03     |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 26.2        |
# |    ep_rew_mean          | -54.9       |
# | time/                   |             |
# |    fps                  | 135         |
# |    iterations           | 113         |
# |    time_elapsed         | 213         |
# |    total_timesteps      | 28928       |
# | train/                  |             |
# |    approx_kl            | 0.008219963 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.472      |
# |    explained_variance   | 0.827       |
# |    learning_rate        | 0.0001      |
# |    loss                 | 565         |
# |    n_updates            | 1120        |
# |    policy_gradient_loss | 0.0133      |
# |    value_loss           | 1.47e+03    |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.1         |
# |    ep_rew_mean          | -54          |
# | time/                   |              |
# |    fps                  | 135          |
# |    iterations           | 114          |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 29184        |
# | train/                  |              |
# |    approx_kl            | 0.0042655277 |
# |    clip_fraction        | 0.133        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.452       |
# |    explained_variance   | 0.741        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.13e+03     |
# |    n_updates            | 1130         |
# |    policy_gradient_loss | 0.00668      |
# |    value_loss           | 2.14e+03     |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 27.6       |
# |    ep_rew_mean          | -62.7      |
# | time/                   |            |
# |    fps                  | 135        |
# |    iterations           | 115        |
# |    time_elapsed         | 217        |
# |    total_timesteps      | 29440      |
# | train/                  |            |
# |    approx_kl            | 0.04428537 |
# |    clip_fraction        | 0.19       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.428     |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.0001     |
# |    loss                 | 385        |
# |    n_updates            | 1140       |
# |    policy_gradient_loss | 0.00499    |
# |    value_loss           | 1.33e+03   |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 26.7         |
# |    ep_rew_mean          | -56          |
# | time/                   |              |
# |    fps                  | 135          |
# |    iterations           | 116          |
# |    time_elapsed         | 218          |
# |    total_timesteps      | 29696        |
# | train/                  |              |
# |    approx_kl            | 0.0124168955 |
# |    clip_fraction        | 0.112        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.402       |
# |    explained_variance   | 0.636        |
# |    learning_rate        | 0.0001       |
# |    loss                 | 1.15e+03     |
# |    n_updates            | 1150         |
# |    policy_gradient_loss | -0.00214     |
# |    value_loss           | 2.24e+03     |
# ------------------------------------------
